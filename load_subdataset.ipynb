# %%
! python3 process.py download -c "Acoustic guitar" -d '/nas/siyu/audioset'
# Out:
# ...
# /nas/siyu/audioset/Acoustic guitar.csv
# A CSV file for class Acoustic guitar already exists.
# *** Overwriting /nas/siyu/audioset/Acoustic guitar.csv ***
# Label ID for "Acoustic guitar": ['/m/042v_gx']
# Finished writing CSV file for Acoustic guitar
# dst_dir: /nas/siyu/audioset/Acoustic guitar
# WARNING: "-f best" selects the best pre-merged format which is often not the best option.
#          To let yt-dlp download and merge the best available formats, simply do not pass any format selection.
#          If you know what you are doing and want only the best pre-merged format, use "-f b" instead to suppress this warning
# ...
